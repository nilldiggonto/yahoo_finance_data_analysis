# %%
import pandas as pd

# %%
import yfinance as yf

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette='rainbow')

# %%
#Import and Export Stock Price Data

# %%
ticker = ['AAPL','BA','KO','IBM','DIS','MSFT']
#Apple  #Boeing #coca-cola #IBM #DISney #MicroSoFT

# %%
#download

# %%
yf.download('AAPL',start='2010-01-01', end='2019-02-06')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2009-12-31   7.611786   7.619643   7.520000   7.526072   6.503574  352410800
# 2010-01-04   7.622500   7.660714   7.585000   7.643214   6.604801  493729600
# 2010-01-05   7.664286   7.699643   7.616071   7.656428   6.616219  601904800
# 2010-01-06   7.656428   7.686786   7.526786   7.534643   6.510980  552160000
# 2010-01-07   7.562500   7.571429   7.466072   7.520714   6.498945  477131200
# ...               ...        ...        ...        ...        ...        ...
# 2019-01-30  40.812500  41.537498  40.057499  41.312500  40.422104  244439200
# 2019-01-31  41.527500  42.250000  41.139999  41.610001  40.713184  162958400
# 2019-02-01  41.740002  42.244999  41.482498  41.630001  40.732758  130672400
# 2019-02-04  41.852501  42.915001  41.820000  42.812500  41.889771  125982000
# ...

# %%
stock = yf.download(ticker,start='2010-01-01',end='2019-02-06')
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stock.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.503574  41.856789  28.090706  92.406113  18.951757  23.801456
# 2010-01-04  6.604801  43.441975  27.933924  93.500313  18.965061  24.168472
# 2010-01-05  6.616219  44.864773  27.864237  92.370834  18.735643  24.176279
# 2010-01-06  6.510980  46.225727  27.716166  91.770790  18.728989  24.027906
# 2010-01-07  6.498945  48.097031  27.724878  91.453102  18.682440  23.778025
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526072  54.130001  32.25  130.899994  ...  32.27  132.410004
# 2010-01-04  7.643214  56.180000  32.07  132.449997  ...  32.50  131.179993
# ...

# %%
stock.tail()
# Out:
#             Adj Close                                                 \
#                  AAPL          BA         DIS         IBM         KO
# Date
# 2019-01-30  40.422104  376.746277  108.800331  123.606735  45.206810
# 2019-01-31  40.713184  374.705688  110.173546  123.643517  45.461830
# 2019-02-01  40.732758  376.464508  109.956207  123.349197  46.000240
# 2019-02-04  41.889771  385.763641  110.450172  124.351791  46.519749
# 2019-02-05  42.606483  398.570557  111.299789  124.682930  46.529194
#
#                             Close                                      ...  \
#                   MSFT       AAPL          BA         DIS         IBM  ...
# Date                                                                   ...
# 2019-01-30  104.002670  41.312500  387.720001  110.129997  134.380005  ...
# 2019-01-31  102.096245  41.610001  385.619995  111.519997  134.419998  ...
# 2019-02-01  100.483116  41.630001  387.429993  111.300003  134.100006  ...
# ...

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2289 entries, 2009-12-31 to 2019-02-05
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2289 non-null   float64
#  1   (Adj Close, BA)    2289 non-null   float64
#  2   (Adj Close, DIS)   2289 non-null   float64
#  3   (Adj Close, IBM)   2289 non-null   float64
#  4   (Adj Close, KO)    2289 non-null   float64
#  5   (Adj Close, MSFT)  2289 non-null   float64
#  6   (Close, AAPL)      2289 non-null   float64
#  7   (Close, BA)        2289 non-null   float64
#  8   (Close, DIS)       2289 non-null   float64
#  9   (Close, IBM)       2289 non-null   float64
#  10  (Close, KO)        2289 non-null   float64
#  11  (Close, MSFT)      2289 non-null   float64
#  12  (High, AAPL)       2289 non-null   float64
#  13  (High, BA)         2289 non-null   float64
#  14  (High, DIS)        2289 non-null   float64
# ...

# %%
###saving the file

# %%
stock.to_csv('stocks.csv')

# %%
pd.read_csv('stocks.csv')
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  BA                 DIS
# 1           Date                 NaN                 NaN                 NaN
# 2     2009-12-31   6.503574371337891  41.856788635253906   28.09070587158203
# 3     2010-01-04   6.604801177978516   43.44197463989258  27.933923721313477
# 4     2010-01-05  6.6162190437316895   44.86477279663086   27.86423683166504
# ...          ...                 ...                 ...                 ...
# 2286  2019-01-30   40.42210388183594  376.74627685546875  108.80033111572266
# 2287  2019-01-31   40.71318435668945   374.7056884765625  110.17354583740234
# 2288  2019-02-01  40.732757568359375   376.4645080566406  109.95620727539062
# 2289  2019-02-04    41.8897705078125   385.7636413574219   110.4501724243164
# 2290  2019-02-05  42.606483459472656    398.570556640625  111.29978942871094
#
# ...

# %%
pd.read_csv('stocks.csv',header=[0,1])
# Out:
#      Unnamed: 0_level_0  Adj Close                                      \
#      Unnamed: 0_level_1       AAPL          BA         DIS         IBM
# 0                  Date        NaN         NaN         NaN         NaN
# 1            2009-12-31   6.503574   41.856789   28.090706   92.406113
# 2            2010-01-04   6.604801   43.441975   27.933924   93.500313
# 3            2010-01-05   6.616219   44.864773   27.864237   92.370834
# 4            2010-01-06   6.510980   46.225727   27.716166   91.770790
# ...                 ...        ...         ...         ...         ...
# 2285         2019-01-30  40.422104  376.746277  108.800331  123.606735
# 2286         2019-01-31  40.713184  374.705688  110.173546  123.643517
# 2287         2019-02-01  40.732758  376.464508  109.956207  123.349197
# 2288         2019-02-04  41.889771  385.763641  110.450172  124.351791
# 2289         2019-02-05  42.606483  398.570557  111.299789  124.682930
#
# ...

# %%
pd.read_csv('stocks.csv',header=[0,1],index_col=[0])
# Out:
#             Adj Close                                                 \
#                  AAPL          BA         DIS         IBM         KO
# Date
# 2009-12-31   6.503574   41.856789   28.090706   92.406113  18.951757
# 2010-01-04   6.604801   43.441975   27.933924   93.500313  18.965061
# 2010-01-05   6.616219   44.864773   27.864237   92.370834  18.735643
# 2010-01-06   6.510980   46.225727   27.716166   91.770790  18.728989
# 2010-01-07   6.498945   48.097031   27.724878   91.453102  18.682440
# ...               ...         ...         ...         ...        ...
# 2019-01-30  40.422104  376.746277  108.800331  123.606735  45.206810
# 2019-01-31  40.713184  374.705688  110.173546  123.643517  45.461830
# 2019-02-01  40.732758  376.464508  109.956207  123.349197  46.000240
# 2019-02-04  41.889771  385.763641  110.450172  124.351791  46.519749
# 2019-02-05  42.606483  398.570557  111.299789  124.682930  46.529194
#
# ...

# %%
stock_2 =pd.read_csv('stocks.csv',header=[0,1],index_col=[0],parse_dates=[0])

# %%
stock_2.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.503574  41.856789  28.090706  92.406113  18.951757  23.801456
# 2010-01-04  6.604801  43.441975  27.933924  93.500313  18.965061  24.168472
# 2010-01-05  6.616219  44.864773  27.864237  92.370834  18.735643  24.176279
# 2010-01-06  6.510980  46.225727  27.716166  91.770790  18.728989  24.027906
# 2010-01-07  6.498945  48.097031  27.724878  91.453102  18.682440  23.778025
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526072  54.130001  32.25  130.899994  ...  32.27  132.410004
# 2010-01-04  7.643214  56.180000  32.07  132.449997  ...  32.50  131.179993
# ...

# %%
stock_2.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'BA'),
#             ('Adj Close',  'DIS'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close',   'KO'),
#             ('Adj Close', 'MSFT'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'BA'),
#             (    'Close',  'DIS'),
#             (    'Close',  'IBM'),
#             (    'Close',   'KO'),
#             (    'Close', 'MSFT'),
#             (     'High', 'AAPL'),
#             (     'High',   'BA'),
#             (     'High',  'DIS'),
#             (     'High',  'IBM'),
#             (     'High',   'KO'),
#             (     'High', 'MSFT'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'BA'),
#             (      'Low',  'DIS'),
#             (      'Low',  'IBM'),
#             (      'Low',   'KO'),
#             (      'Low', 'MSFT'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'BA'),
#             (     'Open',  'DIS'),
# ...

# %%
stock_2.columns.to_flat_index()
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'BA'),  ('Adj Close', 'DIS'),
#         ('Adj Close', 'IBM'),   ('Adj Close', 'KO'), ('Adj Close', 'MSFT'),
#            ('Close', 'AAPL'),       ('Close', 'BA'),      ('Close', 'DIS'),
#             ('Close', 'IBM'),       ('Close', 'KO'),     ('Close', 'MSFT'),
#             ('High', 'AAPL'),        ('High', 'BA'),       ('High', 'DIS'),
#              ('High', 'IBM'),        ('High', 'KO'),      ('High', 'MSFT'),
#              ('Low', 'AAPL'),         ('Low', 'BA'),        ('Low', 'DIS'),
#               ('Low', 'IBM'),         ('Low', 'KO'),       ('Low', 'MSFT'),
#             ('Open', 'AAPL'),        ('Open', 'BA'),       ('Open', 'DIS'),
#              ('Open', 'IBM'),        ('Open', 'KO'),      ('Open', 'MSFT'),
#           ('Volume', 'AAPL'),      ('Volume', 'BA'),     ('Volume', 'DIS'),
#            ('Volume', 'IBM'),      ('Volume', 'KO'),    ('Volume', 'MSFT')],
#       dtype='object')

# %%
stock_2.columns = stock_2.columns.to_flat_index()

# %%
stock_2.head()
# Out:
#             (Adj Close, AAPL)  (Adj Close, BA)  (Adj Close, DIS)  \
# Date
# 2009-12-31           6.503574        41.856789         28.090706
# 2010-01-04           6.604801        43.441975         27.933924
# 2010-01-05           6.616219        44.864773         27.864237
# 2010-01-06           6.510980        46.225727         27.716166
# 2010-01-07           6.498945        48.097031         27.724878
#
#             (Adj Close, IBM)  (Adj Close, KO)  (Adj Close, MSFT)  \
# Date
# 2009-12-31         92.406113        18.951757          23.801456
# 2010-01-04         93.500313        18.965061          24.168472
# 2010-01-05         92.370834        18.735643          24.176279
# 2010-01-06         91.770790        18.728989          24.027906
# 2010-01-07         91.453102        18.682440          23.778025
#
#             (Close, AAPL)  (Close, BA)  (Close, DIS)  (Close, IBM)  ...  \
# Date                                                                ...
# ...

# %%
###multi  index

# %%
stock_3 = stock_2.copy()

# %%
stock_3.columns = pd.MultiIndex.from_tuples(stock_3.columns)

# %%
stock_3.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.503574  41.856789  28.090706  92.406113  18.951757  23.801456
# 2010-01-04  6.604801  43.441975  27.933924  93.500313  18.965061  24.168472
# 2010-01-05  6.616219  44.864773  27.864237  92.370834  18.735643  24.176279
# 2010-01-06  6.510980  46.225727  27.716166  91.770790  18.728989  24.027906
# 2010-01-07  6.498945  48.097031  27.724878  91.453102  18.682440  23.778025
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526072  54.130001  32.25  130.899994  ...  32.27  132.410004
# 2010-01-04  7.643214  56.180000  32.07  132.449997  ...  32.50  131.179993
# ...

# %%
##swapping

# %%
stock_3.swaplevel(axis=1).sort_index(axis=1)
# Out:
#                  AAPL                                                         \
#             Adj Close      Close       High        Low       Open     Volume
# Date
# 2009-12-31   6.503574   7.526072   7.619643   7.520000   7.611786  352410800
# 2010-01-04   6.604801   7.643214   7.660714   7.585000   7.622500  493729600
# 2010-01-05   6.616219   7.656428   7.699643   7.616071   7.664286  601904800
# 2010-01-06   6.510980   7.534643   7.686786   7.526786   7.656428  552160000
# 2010-01-07   6.498945   7.520714   7.571429   7.466072   7.562500  477131200
# ...               ...        ...        ...        ...        ...        ...
# 2019-01-30  40.422104  41.312500  41.537498  40.057499  40.812500  244439200
# 2019-01-31  40.713184  41.610001  42.250000  41.139999  41.527500  162958400
# 2019-02-01  40.732758  41.630001  42.244999  41.482498  41.740002  130672400
# 2019-02-04  41.889771  42.812500  42.915001  41.820000  41.852501  125982000
# ...

# %%
stock_2.to_csv('stock_2.csv')

# %%
stock_4 = stock_3.swaplevel(axis=1).sort_index(axis=1)
